# %% [markdown]
# ## generate erdos training dataset for TELGEN

# %%
from solver.linprog import linprog
from tqdm import tqdm

import gzip
import pickle
import torch
from scipy.linalg import LinAlgWarning
from scipy.optimize._optimize import OptimizeWarning
# from scipy.optimize import OptimizeWarning
import warnings
import numpy as np
from functools import partial
import random
import pickle

# %%
root = 'raw/'

# %% [markdown]
# ### Resource Allocation

# %% [markdown]
# #### input: for one graph
# #### G(V, E, c): random graph (strongly connected)
# #### (s, t, d) \in [S, T, D]
# #### for every (s, t, d), there is a set p \in Pd (k-shortest path algorithm (4/5/6))

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ### generate and save connected and directed ER graph different nodes and p
# ### generate capacities for these graphs

# %%
np.random.seed(2024)

def generate_random_capacities(graph):
    for u, v in graph.edges():
        # Generate a random capacity for the edge (u, v)
        capacity = random.uniform(1000, 5000)  # Adjust the range as needed
        # Assign the capacity as an attribute to the edge
        graph[u][v]['capacity'] = capacity
        
        
# generate a directed er graph
# 9*7 = 63
num_nodes = [20, 30, 40, 50, 60, 70, 80, 90, 100] # number of nodes for creating ER random graph
P = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9] # Probability for creating edges in ER random graph

for p in P:
    for n in num_nodes:
        
        # Generate an ER random graph same as nx.erdos_renyi_graph, but faster
        er_graph = nx.fast_gnp_random_graph(n, p, seed=2024, directed=False)
        
        # Generate capacity for this graph
        generate_random_capacities(er_graph)
        Capacity = {}
        for u, v in er_graph.edges():
            Capacity[(u, v)] = er_graph[u][v]['capacity']
        # save
        with open(root+'erdos_graph/Edge_C_' + str(n) + 'n_' + str(p) + 'p.pkl', 'wb') as f:
            pickle.dump(Capacity, f)
        print('Add capacity to one edge first:', len(Capacity.keys()))
        
        # use undirected erdos graph and add .to_directed (symmetric)
        G = er_graph.to_directed()
        print('Strongly connected:', nx.is_strongly_connected(G))
        print('# of nodes and edges, p:', G.number_of_nodes(), G.number_of_edges(), p)
        # nx.draw(G, with_labels=True, node_color='lightgreen', arrows=True)    
        # save
        nx.write_graphml(G, root+'erdos_graph/er_graph_' + str(n) + 'n_' + str(p) + 'p.graphml')
        print('----------------------------------------')
# Out:
# Add capacity to one edge first: 53
# Strongly connected: True
# # of nodes and edges, p: 20 106 0.3
# ----------------------------------------
# Add capacity to one edge first: 130
# Strongly connected: True
# # of nodes and edges, p: 30 260 0.3
# ----------------------------------------
# Add capacity to one edge first: 241
# Strongly connected: True
# # of nodes and edges, p: 40 482 0.3
# ----------------------------------------
# Add capacity to one edge first: 375
# Strongly connected: True
# # of nodes and edges, p: 50 750 0.3
# ----------------------------------------
# Add capacity to one edge first: 535
# Strongly connected: True
# # of nodes and edges, p: 60 1070 0.3
# ----------------------------------------
# Add capacity to one edge first: 719
# Strongly connected: True
# # of nodes and edges, p: 70 1438 0.3
# ----------------------------------------
# Add capacity to one edge first: 914
# Strongly connected: True
# # of nodes and edges, p: 80 1828 0.3
# ----------------------------------------
# Add capacity to one edge first: 1186
# Strongly connected: True
# # of nodes and edges, p: 90 2372 0.3
# ----------------------------------------
# Add capacity to one edge first: 1453
# Strongly connected: True
# # of nodes and edges, p: 100 2906 0.3
# ----------------------------------------
# Add capacity to one edge first: 69
# Strongly connected: True
# # of nodes and edges, p: 20 138 0.4
# ----------------------------------------
# Add capacity to one edge first: 172
# Strongly connected: True
# # of nodes and edges, p: 30 344 0.4
# ----------------------------------------
# Add capacity to one edge first: 313
# Strongly connected: True
# # of nodes and edges, p: 40 626 0.4
# ----------------------------------------
# Add capacity to one edge first: 487
# Strongly connected: True
# # of nodes and edges, p: 50 974 0.4
# ----------------------------------------
# Add capacity to one edge first: 705
# Strongly connected: True
# # of nodes and edges, p: 60 1410 0.4
# ----------------------------------------
# Add capacity to one edge first: 931
# Strongly connected: True
# # of nodes and edges, p: 70 1862 0.4
# ----------------------------------------
# Add capacity to one edge first: 1239
# Strongly connected: True
# # of nodes and edges, p: 80 2478 0.4
# ----------------------------------------
# Add capacity to one edge first: 1569
# Strongly connected: True
# # of nodes and edges, p: 90 3138 0.4
# ----------------------------------------
# Add capacity to one edge first: 1941
# Strongly connected: True
# # of nodes and edges, p: 100 3882 0.4
# ----------------------------------------
# Add capacity to one edge first: 98
# Strongly connected: True
# # of nodes and edges, p: 20 196 0.5
# ----------------------------------------
# Add capacity to one edge first: 223
# Strongly connected: True
# # of nodes and edges, p: 30 446 0.5
# ----------------------------------------
# Add capacity to one edge first: 403
# Strongly connected: True
# # of nodes and edges, p: 40 806 0.5
# ----------------------------------------
# Add capacity to one edge first: 610
# Strongly connected: True
# # of nodes and edges, p: 50 1220 0.5
# ----------------------------------------
# Add capacity to one edge first: 860
# Strongly connected: True
# # of nodes and edges, p: 60 1720 0.5
# ----------------------------------------
# Add capacity to one edge first: 1197
# Strongly connected: True
# # of nodes and edges, p: 70 2394 0.5
# ----------------------------------------
# Add capacity to one edge first: 1560
# Strongly connected: True
# # of nodes and edges, p: 80 3120 0.5
# ----------------------------------------
# Add capacity to one edge first: 1973
# Strongly connected: True
# # of nodes and edges, p: 90 3946 0.5
# ----------------------------------------
# Add capacity to one edge first: 2429
# Strongly connected: True
# # of nodes and edges, p: 100 4858 0.5
# ----------------------------------------
# Add capacity to one edge first: 111
# Strongly connected: True
# # of nodes and edges, p: 20 222 0.6
# ----------------------------------------
# Add capacity to one edge first: 262
# Strongly connected: True
# # of nodes and edges, p: 30 524 0.6
# ----------------------------------------
# Add capacity to one edge first: 458
# Strongly connected: True
# # of nodes and edges, p: 40 916 0.6
# ----------------------------------------
# Add capacity to one edge first: 722
# Strongly connected: True
# # of nodes and edges, p: 50 1444 0.6
# ----------------------------------------
# Add capacity to one edge first: 1030
# Strongly connected: True
# # of nodes and edges, p: 60 2060 0.6
# ----------------------------------------
# Add capacity to one edge first: 1420
# Strongly connected: True
# # of nodes and edges, p: 70 2840 0.6
# ----------------------------------------
# Add capacity to one edge first: 1860
# Strongly connected: True
# # of nodes and edges, p: 80 3720 0.6
# ----------------------------------------
# Add capacity to one edge first: 2349
# Strongly connected: True
# # of nodes and edges, p: 90 4698 0.6
# ----------------------------------------
# Add capacity to one edge first: 2915
# Strongly connected: True
# # of nodes and edges, p: 100 5830 0.6
# ----------------------------------------
# Add capacity to one edge first: 129
# Strongly connected: True
# # of nodes and edges, p: 20 258 0.7
# ----------------------------------------
# Add capacity to one edge first: 299
# Strongly connected: True
# # of nodes and edges, p: 30 598 0.7
# ----------------------------------------
# Add capacity to one edge first: 541
# Strongly connected: True
# # of nodes and edges, p: 40 1082 0.7
# ----------------------------------------
# Add capacity to one edge first: 835
# Strongly connected: True
# # of nodes and edges, p: 50 1670 0.7
# ----------------------------------------
# Add capacity to one edge first: 1224
# Strongly connected: True
# # of nodes and edges, p: 60 2448 0.7
# ----------------------------------------
# Add capacity to one edge first: 1668
# Strongly connected: True
# # of nodes and edges, p: 70 3336 0.7
# ----------------------------------------
# Add capacity to one edge first: 2195
# Strongly connected: True
# # of nodes and edges, p: 80 4390 0.7
# ----------------------------------------
# Add capacity to one edge first: 2774
# Strongly connected: True
# # of nodes and edges, p: 90 5548 0.7
# ----------------------------------------
# Add capacity to one edge first: 3442
# Strongly connected: True
# # of nodes and edges, p: 100 6884 0.7
# ----------------------------------------
# Add capacity to one edge first: 149
# Strongly connected: True
# # of nodes and edges, p: 20 298 0.8
# ----------------------------------------
# Add capacity to one edge first: 349
# Strongly connected: True
# # of nodes and edges, p: 30 698 0.8
# ----------------------------------------
# Add capacity to one edge first: 621
# Strongly connected: True
# # of nodes and edges, p: 40 1242 0.8
# ----------------------------------------
# Add capacity to one edge first: 958
# Strongly connected: True
# # of nodes and edges, p: 50 1916 0.8
# ----------------------------------------
# Add capacity to one edge first: 1403
# Strongly connected: True
# # of nodes and edges, p: 60 2806 0.8
# ----------------------------------------
# Add capacity to one edge first: 1917
# Strongly connected: True
# # of nodes and edges, p: 70 3834 0.8
# ----------------------------------------
# Add capacity to one edge first: 2494
# Strongly connected: True
# # of nodes and edges, p: 80 4988 0.8
# ----------------------------------------
# Add capacity to one edge first: 3183
# Strongly connected: True
# # of nodes and edges, p: 90 6366 0.8
# ----------------------------------------
# Add capacity to one edge first: 3940
# Strongly connected: True
# # of nodes and edges, p: 100 7880 0.8
# ----------------------------------------
# Add capacity to one edge first: 169
# Strongly connected: True
# # of nodes and edges, p: 20 338 0.9
# ----------------------------------------
# Add capacity to one edge first: 393
# Strongly connected: True
# # of nodes and edges, p: 30 786 0.9
# ----------------------------------------
# Add capacity to one edge first: 703
# Strongly connected: True
# # of nodes and edges, p: 40 1406 0.9
# ----------------------------------------
# Add capacity to one edge first: 1095
# Strongly connected: True
# # of nodes and edges, p: 50 2190 0.9
# ----------------------------------------
# Add capacity to one edge first: 1585
# Strongly connected: True
# # of nodes and edges, p: 60 3170 0.9
# ----------------------------------------
# Add capacity to one edge first: 2167
# Strongly connected: True
# # of nodes and edges, p: 70 4334 0.9
# ----------------------------------------
# Add capacity to one edge first: 2833
# Strongly connected: True
# # of nodes and edges, p: 80 5666 0.9
# ----------------------------------------
# Add capacity to one edge first: 3602
# Strongly connected: True
# # of nodes and edges, p: 90 7204 0.9
# ----------------------------------------
# Add capacity to one edge first: 4465
# Strongly connected: True
# # of nodes and edges, p: 100 8930 0.9
# ----------------------------------------

# %% [markdown]
# ### generate k-shortest path

# %%
from itertools import islice
def k_shortest_paths(G, source, target, k, weight=None):
    return list(islice(nx.shortest_simple_paths(G, source, target, weight=weight), k))

# %% [markdown]
# ### Read all graphs and their capacities and load as a group

# %%
#### select graphs ####
num_nodes = [20, 30, 40, 50, 60, 70, 80, 90, 100] # number of nodes for creating ER random graph
P = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9] # Probability for creating edges in ER random graph
ran_group = []
ran_group_noC = []
for p in P:
    for n in num_nodes:

        G = nx.read_graphml(root+'erdos_graph/er_graph_' + str(n) + 'n_' + str(p) + 'p.graphml')
        ran_group_noC.append(G)
        print('Graph info', G.number_of_nodes(), G.number_of_edges())
        print('Connected:', nx.is_strongly_connected(G))
        with open(root+'erdos_graph/Edge_C_' + str(n) + 'n_' + str(p) + 'p.pkl', 'rb') as f:
            Edge_C = pickle.load(f)
        print('Len capacity keys:', len(Edge_C.keys()))
        g_test = nx.DiGraph(G)
        for u, v in G.edges():
            if (int(u), int(v)) in Edge_C.keys():
                g_test.add_edge(u, v, weight=Edge_C[(int(u), int(v))])
            else:
                g_test.add_edge(u, v, weight=Edge_C[(int(v), int(u))])
        ran_group.append(g_test)
        print('After adding Capacity info', g_test.number_of_nodes(), g_test.number_of_edges())
        print('Connected:', nx.is_strongly_connected(g_test))
        print('-------------------------------------')
# Out:
# Graph info 20 106
# Connected: True
# Len capacity keys: 53
# After adding Capacity info 20 106
# Connected: True
# -------------------------------------
# Graph info 30 260
# Connected: True
# Len capacity keys: 130
# After adding Capacity info 30 260
# Connected: True
# -------------------------------------
# Graph info 40 482
# Connected: True
# Len capacity keys: 241
# After adding Capacity info 40 482
# Connected: True
# -------------------------------------
# Graph info 50 750
# Connected: True
# Len capacity keys: 375
# After adding Capacity info 50 750
# Connected: True
# -------------------------------------
# Graph info 60 1070
# Connected: True
# Len capacity keys: 535
# After adding Capacity info 60 1070
# Connected: True
# -------------------------------------
# Graph info 70 1438
# Connected: True
# Len capacity keys: 719
# After adding Capacity info 70 1438
# Connected: True
# -------------------------------------
# Graph info 80 1828
# Connected: True
# Len capacity keys: 914
# After adding Capacity info 80 1828
# Connected: True
# -------------------------------------
# Graph info 90 2372
# Connected: True
# Len capacity keys: 1186
# After adding Capacity info 90 2372
# Connected: True
# -------------------------------------
# Graph info 100 2906
# Connected: True
# Len capacity keys: 1453
# After adding Capacity info 100 2906
# Connected: True
# -------------------------------------
# Graph info 20 138
# Connected: True
# Len capacity keys: 69
# After adding Capacity info 20 138
# Connected: True
# -------------------------------------
# Graph info 30 344
# Connected: True
# Len capacity keys: 172
# After adding Capacity info 30 344
# Connected: True
# -------------------------------------
# Graph info 40 626
# Connected: True
# Len capacity keys: 313
# After adding Capacity info 40 626
# Connected: True
# -------------------------------------
# Graph info 50 974
# Connected: True
# Len capacity keys: 487
# After adding Capacity info 50 974
# Connected: True
# -------------------------------------
# Graph info 60 1410
# Connected: True
# Len capacity keys: 705
# After adding Capacity info 60 1410
# Connected: True
# -------------------------------------
# Graph info 70 1862
# Connected: True
# Len capacity keys: 931
# After adding Capacity info 70 1862
# Connected: True
# -------------------------------------
# Graph info 80 2478
# Connected: True
# Len capacity keys: 1239
# After adding Capacity info 80 2478
# Connected: True
# -------------------------------------
# Graph info 90 3138
# Connected: True
# Len capacity keys: 1569
# After adding Capacity info 90 3138
# Connected: True
# -------------------------------------
# Graph info 100 3882
# Connected: True
# Len capacity keys: 1941
# After adding Capacity info 100 3882
# Connected: True
# -------------------------------------
# Graph info 20 196
# Connected: True
# Len capacity keys: 98
# After adding Capacity info 20 196
# Connected: True
# -------------------------------------
# Graph info 30 446
# Connected: True
# Len capacity keys: 223
# After adding Capacity info 30 446
# Connected: True
# -------------------------------------
# Graph info 40 806
# Connected: True
# Len capacity keys: 403
# After adding Capacity info 40 806
# Connected: True
# -------------------------------------
# Graph info 50 1220
# Connected: True
# Len capacity keys: 610
# After adding Capacity info 50 1220
# Connected: True
# -------------------------------------
# Graph info 60 1720
# Connected: True
# Len capacity keys: 860
# After adding Capacity info 60 1720
# Connected: True
# -------------------------------------
# Graph info 70 2394
# Connected: True
# Len capacity keys: 1197
# After adding Capacity info 70 2394
# Connected: True
# -------------------------------------
# Graph info 80 3120
# Connected: True
# Len capacity keys: 1560
# After adding Capacity info 80 3120
# Connected: True
# -------------------------------------
# Graph info 90 3946
# Connected: True
# Len capacity keys: 1973
# After adding Capacity info 90 3946
# Connected: True
# -------------------------------------
# Graph info 100 4858
# Connected: True
# Len capacity keys: 2429
# After adding Capacity info 100 4858
# Connected: True
# -------------------------------------
# Graph info 20 222
# Connected: True
# Len capacity keys: 111
# After adding Capacity info 20 222
# Connected: True
# -------------------------------------
# Graph info 30 524
# Connected: True
# Len capacity keys: 262
# After adding Capacity info 30 524
# Connected: True
# -------------------------------------
# Graph info 40 916
# Connected: True
# Len capacity keys: 458
# After adding Capacity info 40 916
# Connected: True
# -------------------------------------
# Graph info 50 1444
# Connected: True
# Len capacity keys: 722
# After adding Capacity info 50 1444
# Connected: True
# -------------------------------------
# Graph info 60 2060
# Connected: True
# Len capacity keys: 1030
# After adding Capacity info 60 2060
# Connected: True
# -------------------------------------
# Graph info 70 2840
# Connected: True
# Len capacity keys: 1420
# After adding Capacity info 70 2840
# Connected: True
# -------------------------------------
# Graph info 80 3720
# Connected: True
# Len capacity keys: 1860
# After adding Capacity info 80 3720
# Connected: True
# -------------------------------------
# Graph info 90 4698
# Connected: True
# Len capacity keys: 2349
# After adding Capacity info 90 4698
# Connected: True
# -------------------------------------
# Graph info 100 5830
# Connected: True
# Len capacity keys: 2915
# After adding Capacity info 100 5830
# Connected: True
# -------------------------------------
# Graph info 20 258
# Connected: True
# Len capacity keys: 129
# After adding Capacity info 20 258
# Connected: True
# -------------------------------------
# Graph info 30 598
# Connected: True
# Len capacity keys: 299
# After adding Capacity info 30 598
# Connected: True
# -------------------------------------
# Graph info 40 1082
# Connected: True
# Len capacity keys: 541
# After adding Capacity info 40 1082
# Connected: True
# -------------------------------------
# Graph info 50 1670
# Connected: True
# Len capacity keys: 835
# After adding Capacity info 50 1670
# Connected: True
# -------------------------------------
# Graph info 60 2448
# Connected: True
# Len capacity keys: 1224
# After adding Capacity info 60 2448
# Connected: True
# -------------------------------------
# Graph info 70 3336
# Connected: True
# Len capacity keys: 1668
# After adding Capacity info 70 3336
# Connected: True
# -------------------------------------
# Graph info 80 4390
# Connected: True
# Len capacity keys: 2195
# After adding Capacity info 80 4390
# Connected: True
# -------------------------------------
# Graph info 90 5548
# Connected: True
# Len capacity keys: 2774
# After adding Capacity info 90 5548
# Connected: True
# -------------------------------------
# Graph info 100 6884
# Connected: True
# Len capacity keys: 3442
# After adding Capacity info 100 6884
# Connected: True
# -------------------------------------
# Graph info 20 298
# Connected: True
# Len capacity keys: 149
# After adding Capacity info 20 298
# Connected: True
# -------------------------------------
# Graph info 30 698
# Connected: True
# Len capacity keys: 349
# After adding Capacity info 30 698
# Connected: True
# -------------------------------------
# Graph info 40 1242
# Connected: True
# Len capacity keys: 621
# After adding Capacity info 40 1242
# Connected: True
# -------------------------------------
# Graph info 50 1916
# Connected: True
# Len capacity keys: 958
# After adding Capacity info 50 1916
# Connected: True
# -------------------------------------
# Graph info 60 2806
# Connected: True
# Len capacity keys: 1403
# After adding Capacity info 60 2806
# Connected: True
# -------------------------------------
# Graph info 70 3834
# Connected: True
# Len capacity keys: 1917
# After adding Capacity info 70 3834
# Connected: True
# -------------------------------------
# Graph info 80 4988
# Connected: True
# Len capacity keys: 2494
# After adding Capacity info 80 4988
# Connected: True
# -------------------------------------
# Graph info 90 6366
# Connected: True
# Len capacity keys: 3183
# After adding Capacity info 90 6366
# Connected: True
# -------------------------------------
# Graph info 100 7880
# Connected: True
# Len capacity keys: 3940
# After adding Capacity info 100 7880
# Connected: True
# -------------------------------------
# Graph info 20 338
# Connected: True
# Len capacity keys: 169
# After adding Capacity info 20 338
# Connected: True
# -------------------------------------
# Graph info 30 786
# Connected: True
# Len capacity keys: 393
# After adding Capacity info 30 786
# Connected: True
# -------------------------------------
# Graph info 40 1406
# Connected: True
# Len capacity keys: 703
# After adding Capacity info 40 1406
# Connected: True
# -------------------------------------
# Graph info 50 2190
# Connected: True
# Len capacity keys: 1095
# After adding Capacity info 50 2190
# Connected: True
# -------------------------------------
# Graph info 60 3170
# Connected: True
# Len capacity keys: 1585
# After adding Capacity info 60 3170
# Connected: True
# -------------------------------------
# Graph info 70 4334
# Connected: True
# Len capacity keys: 2167
# After adding Capacity info 70 4334
# Connected: True
# -------------------------------------
# Graph info 80 5666
# Connected: True
# Len capacity keys: 2833
# After adding Capacity info 80 5666
# Connected: True
# -------------------------------------
# Graph info 90 7204
# Connected: True
# Len capacity keys: 3602
# After adding Capacity info 90 7204
# Connected: True
# -------------------------------------
# Graph info 100 8930
# Connected: True
# Len capacity keys: 4465
# After adding Capacity info 100 8930
# Connected: True
# -------------------------------------

# %% [markdown]
# ## function define

# %%
# G: G(V, E, C)                           nx.weighted.graph
# STD: demands align with ST pairs        list[([s1, t1], dmd1), ([s2, t2], dmd2),...], (string, int)
# Pd: set of paths for every st pair      dict{[s1, t1]: [([path1], cost1), ([path2], cost2)...], [s2, t2]...}
# # of std pairs = # of keys in Pd
# k: k shortest path for every (s, t, d) tuple

def generate_reallocation(G, STD, Pd, k):
    
    # constraint 1
    A1 = []
    for i in range(len(STD)):
        a = np.zeros(len(STD)*k)
        a[k*i: k*i+k] = 1
        A1.append(a)
    A1 = np.array(A1)
    b1 = np.ones(len(STD))

    # constrain 2
    edges_list = list(G.edges())
    A2 = np.zeros((G.number_of_edges(), len(STD)*k))

    for i in range(len(STD)):
        paths = Pd[tuple(STD[i][0])] # possible paths
        for j in range(k):
            p = paths[j]   # path[j] is the path
            for n in range(len(p)-1):
                if (p[n], p[n+1]) in edges_list:
                    A2[edges_list.index((p[n], p[n+1]))][k*i+j] = STD[i][1]
                else:
                    continue  
    b2 = np.array(list(nx.get_edge_attributes(G,'weight').values()))
    zero_row_indices = np.where(A2.any(axis=1)==0)[0]
    A2 = np.delete(A2, zero_row_indices, axis=0)
    b2 = np.delete(b2, zero_row_indices, axis=0)

    for i in range(A2.shape[0]):
        A2[i] = A2[i]/b2[i]
        b2[i] = b2[i]/b2[i]
    
    # obj
    c = -1*np.concatenate([np.ones(k)*STD[i][1] for i in range(len(STD))])
        
    return A1, b1, A2, b2, c

# %% [markdown]
# ## train dataset generation

# %%
### gen train ####
import time
warnings.filterwarnings("error")

random.seed(2024)
np.random.seed(2024)


pkg_idx = 0              # instance index for your data generation
success_cnt = 0
fail_cnt = 0
bounds = (0., 1.)

max_iter = 15000
num = 1                  # number of instance generated

k = 4                    # k-shortest path
max_d = 5000             # demand max value
min_d = 1000             # demand min value

number_of_st = 10        # number of st pairs

graph_info = []
for g in range(len(ran_group)):
    stds = []
    ips = []
    success_cnt = 0
    times = []
    for n in range(num): # in case failsure case
        
        # generate st pairs with demand value 
        std = []
        Pd = {}
        count_std = 0
        while count_std != number_of_st:
            st = np.random.choice(ran_group[g].nodes(), 2, replace=False)
            d = random.uniform(min_d, max_d)
            k_paths = k_shortest_paths(ran_group_noC[g], st[0], st[1], k=k)
            if len(k_paths) != k:
                continue
            else:
                Pd[(st[0], st[1])] = k_paths
                std.append((st, d))
                count_std += 1

        A1, b1, A2, b2, c = generate_reallocation(ran_group[g], std, Pd, k)
        A = np.vstack([A1, A2])
        b = np.hstack([b1, b2])
        
        n_time = time.time()
        try:
            A_eq = None
            b_eq = None
            A_ub = A
            b_ub = b
            res = linprog(c, A_ub=A_ub, b_ub=b_ub, A_eq=A_eq, b_eq=b_eq, bounds=bounds, 
                          method='interior-point')
            times.append(time.time()-n_time)
            print(res)

        except (LinAlgWarning, OptimizeWarning, AssertionError):
            fail_cnt += 1
            continue
        else:
            if res.success and not np.isnan(res.fun):
                ips.append((torch.from_numpy(A).to(torch.float), torch.from_numpy(b).to(torch.float), torch.from_numpy(c).to(torch.float)))
                success_cnt += 1
                stds.append(std)
        if success_cnt == num:
            break

    with open(root+'/raw/instance_'+str(pkg_idx)+'_stds.pkl','wb') as f:
        pickle.dump(stds, f)
    with gzip.open(f'{root}/raw/instance_{pkg_idx}.pkl.gz', "wb") as file:
        pickle.dump(ips, file)
    pkg_idx += 1

    graph_info.append((ran_group[g].number_of_nodes(), ran_group[g].number_of_edges(), sum(times)/len(times)))

np.save(root+'/raw/erdos_train_'+str(number_of_st)+'st_info', graph_info)
for i in graph_info:
    print('Graph info and average time used:', i)

    
    
warnings.resetwarnings()
# Out:
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -31165.57472089534
#             x: [ 2.980e-01  2.341e-01 ...  3.032e-01  1.814e-01]
#           nit: 9
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -35319.26537796784
#             x: [ 2.186e-01  2.814e-01 ...  4.243e-01  2.765e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -25084.207697676007
#             x: [ 2.501e-01  2.984e-01 ...  2.764e-01  1.925e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -27989.145798874353
#             x: [ 2.466e-01  3.571e-01 ...  2.540e-01  2.552e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -28446.134844470293
#             x: [ 1.982e-01  4.568e-01 ...  2.500e-01  2.500e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -30444.22417140401
#             x: [ 2.950e-01  2.738e-01 ...  3.289e-01  1.421e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -32773.29807893087
#             x: [ 2.418e-02  3.517e-01 ...  2.198e-01  1.957e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -24942.187121360264
#             x: [ 3.085e-02  4.691e-01 ...  2.771e-01  2.150e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -25268.15926516483
#             x: [ 2.554e-01  2.554e-01 ...  2.523e-01  2.486e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -26153.801219075387
#             x: [ 3.060e-01  1.174e-01 ...  2.906e-01  1.422e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -33208.88541585523
#             x: [ 2.340e-01  1.677e-01 ...  1.395e-01  2.610e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -26376.93562525228
#             x: [ 3.605e-01  3.312e-01 ...  3.507e-01  1.874e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -27662.07939533398
#             x: [ 3.068e-01  2.168e-01 ...  2.500e-01  2.500e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -27419.81207237124
#             x: [ 1.902e-01  2.405e-01 ...  3.217e-01  4.134e-02]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -31819.603119267085
#             x: [ 2.303e-01  1.559e-01 ...  2.081e-01  2.647e-01]
#           nit: 9
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -32898.3287857081
#             x: [ 2.824e-01  1.755e-01 ...  2.311e-01  2.145e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -31796.50570041562
#             x: [ 3.888e-01  3.523e-01 ...  2.438e-01  2.523e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -34310.950296918716
#             x: [ 2.455e-01  2.455e-01 ...  2.322e-01  1.897e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -24941.100326451513
#             x: [ 1.832e-01  3.469e-01 ...  2.277e-01  2.751e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -28685.42944937912
#             x: [ 2.681e-01  3.205e-01 ...  2.564e-01  1.993e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -22155.092570618006
#             x: [ 1.579e-01  2.967e-01 ...  1.426e-01  2.932e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -35121.20517507856
#             x: [ 6.730e-02  3.109e-01 ...  5.897e-02  2.252e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -28608.132646493643
#             x: [ 2.558e-01  2.327e-01 ...  1.939e-01  2.732e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -29068.129218753085
#             x: [ 2.576e-01  2.576e-01 ...  1.847e-01  2.954e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -30848.224135017997
#             x: [ 3.566e-01  7.517e-02 ...  2.530e-01  2.530e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -33413.69277566331
#             x: [ 2.500e-01  2.500e-01 ...  1.768e-01  3.181e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -33980.84888832913
#             x: [ 2.903e-01  2.903e-01 ...  2.344e-01  2.142e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -35165.60023141226
#             x: [ 4.021e-01  2.656e-01 ...  2.392e-01  2.536e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -27703.256690004197
#             x: [ 2.563e-01  2.563e-01 ...  2.650e-01  2.159e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -31869.569834005066
#             x: [ 3.094e-01  1.700e-01 ...  3.333e-01  3.465e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -30592.81876954295
#             x: [ 2.036e-01  2.740e-01 ...  1.994e-02  1.458e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -26990.21019427437
#             x: [ 3.461e-01  4.376e-01 ...  1.922e-01  1.866e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -28251.431990133442
#             x: [ 3.275e-01  2.023e-01 ...  2.464e-01  1.676e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -30664.568579189534
#             x: [ 2.500e-01  2.500e-01 ...  2.482e-01  2.506e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -25481.072884027893
#             x: [ 2.553e-01  2.341e-01 ...  2.500e-01  2.500e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -36325.78350205737
#             x: [ 2.519e-01  2.519e-01 ...  2.537e-01  2.532e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -31602.485967987464
#             x: [ 3.056e-01  4.483e-01 ...  2.429e-01  2.977e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -22094.163454422036
#             x: [ 2.971e-01  1.974e-01 ...  3.980e-02  3.269e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -24513.044028644254
#             x: [ 1.961e-01  3.577e-01 ...  3.363e-01  1.968e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -30489.643480153252
#             x: [ 2.696e-01  2.696e-01 ...  3.966e-01  6.024e-03]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -34514.25657781212
#             x: [ 2.575e-01  2.218e-01 ...  6.507e-02  5.598e-01]
#           nit: 9
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -41867.03335935758
#             x: [ 2.867e-01  1.780e-01 ...  2.121e-01  2.590e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -38120.19773156592
#             x: [ 4.409e-01  2.085e-01 ...  2.005e-01  2.071e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -34773.07758755678
#             x: [ 2.765e-01  1.625e-01 ...  2.192e-01  2.684e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -22966.03757704242
#             x: [ 2.591e-01  2.227e-01 ...  2.500e-01  2.500e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -27697.129569361136
#             x: [ 3.582e-01  3.644e-01 ...  2.870e-01  2.790e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -33157.45077108232
#             x: [ 4.302e-01  1.821e-01 ...  3.482e-01  2.257e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -24364.60180597373
#             x: [ 2.530e-01  2.530e-01 ...  3.267e-01  2.122e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -30360.76977524071
#             x: [ 1.991e-01  2.735e-01 ...  3.099e-01  1.992e-03]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -34240.57193363775
#             x: [ 2.500e-01  2.500e-01 ...  2.651e-01  2.205e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -31897.76001715153
#             x: [ 1.550e-01  1.790e-01 ...  3.364e-01  2.403e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -24657.3126836019
#             x: [ 1.563e-01  2.572e-01 ...  3.166e-01  2.761e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -26692.26147259395
#             x: [ 2.322e-01  3.035e-01 ...  2.996e-01  2.744e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -35751.23732010415
#             x: [ 3.070e-01  2.163e-01 ...  3.132e-01  2.682e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -34526.46066561423
#             x: [ 8.159e-01  3.750e-03 ...  2.652e-01  2.537e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -34502.987472639084
#             x: [ 2.448e-01  2.517e-01 ...  3.359e-01  5.764e-02]
#           nit: 10
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -30963.763174234373
#             x: [ 2.880e-01  2.915e-01 ...  2.557e-01  2.330e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -24674.273348758717
#             x: [ 2.635e-01  2.469e-01 ...  2.500e-01  2.500e-01]
#           nit: 8
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -31920.97445345579
#             x: [ 2.441e-01  2.615e-01 ...  2.687e-01  2.162e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -35600.2688452844
#             x: [ 1.817e-01  2.250e-01 ...  1.721e-01  3.150e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -26040.68889473562
#             x: [ 2.500e-01  2.500e-01 ...  3.079e-01  2.667e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -27752.147318101554
#             x: [ 4.947e-01  1.388e-01 ...  2.500e-01  2.500e-01]
#           nit: 7
#  intermediate: []
#       message: Optimization terminated successfully.
#       success: True
#        status: 0
#           fun: -29518.619270362637
#             x: [ 2.171e-01  2.610e-01 ...  2.454e-01  7.951e-02]
#           nit: 9
#  intermediate: []
# Graph info and average time used: (20, 106, 0.00722813606262207)
# Graph info and average time used: (30, 260, 0.004324913024902344)
# Graph info and average time used: (40, 482, 0.0041620731353759766)
# Graph info and average time used: (50, 750, 0.004082202911376953)
# Graph info and average time used: (60, 1070, 0.005575656890869141)
# Graph info and average time used: (70, 1438, 0.004548311233520508)
# Graph info and average time used: (80, 1828, 0.004063129425048828)
# Graph info and average time used: (90, 2372, 0.00455927848815918)
# Graph info and average time used: (100, 2906, 0.004101991653442383)
# Graph info and average time used: (20, 138, 0.004773616790771484)
# Graph info and average time used: (30, 344, 0.0042154788970947266)
# Graph info and average time used: (40, 626, 0.004062652587890625)
# Graph info and average time used: (50, 974, 0.004083871841430664)
# Graph info and average time used: (60, 1410, 0.004073619842529297)
# Graph info and average time used: (70, 1862, 0.0049664974212646484)
# Graph info and average time used: (80, 2478, 0.004113197326660156)
# Graph info and average time used: (90, 3138, 0.004082679748535156)
# Graph info and average time used: (100, 3882, 0.004510164260864258)
# Graph info and average time used: (20, 196, 0.004673004150390625)
# Graph info and average time used: (30, 446, 0.004128694534301758)
# Graph info and average time used: (40, 806, 0.004113912582397461)
# Graph info and average time used: (50, 1220, 0.004515886306762695)
# Graph info and average time used: (60, 1720, 0.004103899002075195)
# Graph info and average time used: (70, 2394, 0.0041005611419677734)
# Graph info and average time used: (80, 3120, 0.0040967464447021484)
# Graph info and average time used: (90, 3946, 0.004580497741699219)
# Graph info and average time used: (100, 4858, 0.004082202911376953)
# Graph info and average time used: (20, 222, 0.004181861877441406)
# Graph info and average time used: (30, 524, 0.00461125373840332)
# Graph info and average time used: (40, 916, 0.0040814876556396484)
# Graph info and average time used: (50, 1444, 0.00406956672668457)
# Graph info and average time used: (60, 2060, 0.004131317138671875)
# Graph info and average time used: (70, 2840, 0.004553079605102539)
# Graph info and average time used: (80, 3720, 0.004070281982421875)
# Graph info and average time used: (90, 4698, 0.004088878631591797)
# Graph info and average time used: (100, 5830, 0.004126071929931641)
# Graph info and average time used: (20, 258, 0.004117488861083984)
# Graph info and average time used: (30, 598, 0.004588603973388672)
# Graph info and average time used: (40, 1082, 0.004179716110229492)
# Graph info and average time used: (50, 1670, 0.004581451416015625)
# Graph info and average time used: (60, 2448, 0.0049898624420166016)
# Graph info and average time used: (70, 3336, 0.004127979278564453)
# Graph info and average time used: (80, 4390, 0.004068613052368164)
# Graph info and average time used: (90, 5548, 0.0040819644927978516)
# Graph info and average time used: (100, 6884, 0.004148244857788086)
# Graph info and average time used: (20, 298, 0.004214763641357422)
# Graph info and average time used: (30, 698, 0.0041277408599853516)
# Graph info and average time used: (40, 1242, 0.0041310787200927734)
# Graph info and average time used: (50, 1916, 0.004130125045776367)
# Graph info and average time used: (60, 2806, 0.004141092300415039)
# Graph info and average time used: (70, 3834, 0.004534244537353516)
# Graph info and average time used: (80, 4988, 0.004149913787841797)
# Graph info and average time used: (90, 6366, 0.004524946212768555)
# Graph info and average time used: (100, 7880, 0.004118919372558594)
# Graph info and average time used: (20, 338, 0.004634380340576172)
# Graph info and average time used: (30, 786, 0.0054433345794677734)
# Graph info and average time used: (40, 1406, 0.004512786865234375)
# Graph info and average time used: (50, 2190, 0.004527091979980469)
# Graph info and average time used: (60, 3170, 0.0041027069091796875)
# Graph info and average time used: (70, 4334, 0.004539966583251953)
# Graph info and average time used: (80, 5666, 0.004041194915771484)
# Graph info and average time used: (90, 7204, 0.004128456115722656)
# Graph info and average time used: (100, 8930, 0.005059003829956055)
